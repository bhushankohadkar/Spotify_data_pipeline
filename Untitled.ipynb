# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credential_manager=SpotifyClientCredentials(client_id='4c7d022da5fb48bf959dc091ad343f91',client_secret='ced980141567421dadb6d4710098c5fa')

# %%
sp=spotipy.Spotify(client_credentials_manager=client_credential_manager)

# %%
playlist_link='https://open.spotify.com/playlist/37i9dQZF1DWSV8PLJm9riw'

# %%
playlist_URI=playlist_link.split('/')[-1].split('?')[0]

# %%
playlist_URI
# Out:
# '37i9dQZF1DWSV8PLJm9riw'

# %%
# to track playlist
data=sp.playlist_tracks(playlist_URI)

# %%
#list of songs
len(data['items'])
# Out:
# 50

# %%
data['items']
# Out:
# [{'added_at': '2023-11-29T12:18:27Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5NHm4TU5Twz7owibYxJfFU'},
#       'href': 'https://api.spotify.com/v1/artists/5NHm4TU5Twz7owibYxJfFU',
#       'id': '5NHm4TU5Twz7owibYxJfFU',
#       'name': 'King',
#       'type': 'artist',
#       'uri': 'spotify:artist:5NHm4TU5Twz7owibYxJfFU'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2023-11-29T12:18:27Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5NHm4TU5Twz7owibYxJfFU'},
#      'href': 'https://api.spotify.com/v1/artists/5NHm4TU5Twz7owibYxJfFU',
#      'id': '5NHm4TU5Twz7owibYxJfFU',
#      'name': 'King',
#      'type': 'artist',
#      'uri': 'spotify:artist:5NHm4TU5Twz7owibYxJfFU'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '15CyNDuGY5fsG0Hn9rjnpG'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Champagne Talk'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2022-10-12'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 8

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/15CyNDuGY5fsG0Hn9rjnpG'

# %%
album_list=[]
for row in data['items']:
    album_id=row['track']['album']['id']
    album_name=row['track']['album']['name']
    album_release_date=row['track']['album']['release_date']
    album_total_tracks=row['track']['album']['total_tracks']
    album_url=row['track']['album']['external_urls']['spotify']
    album_element={'album_id':album_id,'name':album_name,'release_date':album_release_date,
                   'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
print(album_list)
# Out:
# [{'album_id': '15CyNDuGY5fsG0Hn9rjnpG', 'name': 'Champagne Talk', 'release_date': '2022-10-12', 'total_tracks': 8, 'url': 'https://open.spotify.com/album/15CyNDuGY5fsG0Hn9rjnpG'}, {'album_id': '6BHlJhCk1vjCG6hqTG2SFV', 'name': 'Kahani Suno 2.0', 'release_date': '2022-05-31', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/6BHlJhCk1vjCG6hqTG2SFV'}, {'album_id': '4kIPlpwEZBK9JaI9pZHe79', 'name': 'Brahmastra (Original Motion Picture Soundtrack)', 'release_date': '2022-10-06', 'total_tracks': 9, 'url': 'https://open.spotify.com/album/4kIPlpwEZBK9JaI9pZHe79'}, {'album_id': '7khRLZe8P6XcUoRgOa3nnf', 'name': 'Malang Sajna', 'release_date': '2022-12-19', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/7khRLZe8P6XcUoRgOa3nnf'}, {'album_id': '5AivaZj0CiQJoDWqVH2pbh', 'name': 'Still Rollin', 'release_date': '2023-05-19', 'total_tracks': 7, 'url': 'https://open.spotify.com/album/5AivaZj0CiQJoDWqVH2pbh'}, {'album_id': '1wt2WZBZZ9GhM0AC61l7SS', 'name': 'Heeriye (feat. Arijit Si
# ...

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5NHm4TU5Twz7owibYxJfFU'},
#   'href': 'https://api.spotify.com/v1/artists/5NHm4TU5Twz7owibYxJfFU',
#   'id': '5NHm4TU5Twz7owibYxJfFU',
#   'name': 'King',
#   'type': 'artist',
#   'uri': 'spotify:artist:5NHm4TU5Twz7owibYxJfFU'}]

# %%
artist_list=[]
for row in data['items']:
    for key,value in row.items():
        if key=='track':
            for artist in value['artists']:
                artist_dict= {'artist_id':artist['id'],'artist_name':artist['name'],
                              'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '5NHm4TU5Twz7owibYxJfFU',
#   'artist_name': 'King',
#   'external_url': 'https://api.spotify.com/v1/artists/5NHm4TU5Twz7owibYxJfFU'},
#  {'artist_id': '1n9EM0Y4A89vuRiA93gSS9',
#   'artist_name': 'Kaifi Khalil',
#   'external_url': 'https://api.spotify.com/v1/artists/1n9EM0Y4A89vuRiA93gSS9'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '2fMqTqiTxUDlmcOEPaQSsx',
#   'artist_name': 'Amitabh Bhattacharya',
#   'external_url': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx'},
#  {'artist_id': '6WOdPJmexxFINcKMkP2jMG',
#   'artist_name': 'Sachet Tandon',
#   'external_url': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG'},
#  {'artist_id': '1E6arsXf5Fgsnv9YpSzjpE',
# ...

# %%
song_list=[]
for row in data['items']:
    song_id=row['track']['id']
    song_name=row['track']['name']
    song_duration=row['track']['duration_ms']
    song_url=row['track']['external_urls']['spotify']
    song_popularity=row['track']['popularity']
    song_added=row['added_at']
    album_id=row['track']['album']['id']
    artist_id=row['track']['album']['artists'][0]['id']
    song_element={'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,
                  'url':song_url,'popuarity':song_popularity,'song_added':song_added,
                  'album_id':album_id,'artist_id':artist_id}
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '1418IuVKQPTYqt7QNJ9RXN',
#   'song_name': 'Maan Meri Jaan',
#   'duration_ms': 194653,
#   'url': 'https://open.spotify.com/track/1418IuVKQPTYqt7QNJ9RXN',
#   'popuarity': 79,
#   'song_added': '2023-11-29T12:18:27Z',
#   'album_id': '15CyNDuGY5fsG0Hn9rjnpG',
#   'artist_id': '5NHm4TU5Twz7owibYxJfFU'},
#  {'song_id': '4VsP4Dm8gsibRxB5I2hEkw',
#   'song_name': 'Kahani Suno 2.0',
#   'duration_ms': 173637,
#   'url': 'https://open.spotify.com/track/4VsP4Dm8gsibRxB5I2hEkw',
#   'popuarity': 77,
#   'song_added': '2023-11-29T12:18:27Z',
#   'album_id': '6BHlJhCk1vjCG6hqTG2SFV',
#   'artist_id': '1n9EM0Y4A89vuRiA93gSS9'},
#  {'song_id': '4UMIv5jd9gK98a39BQRD9X',
#   'song_name': 'Kesariya',
#   'duration_ms': 268164,
#   'url': 'https://open.spotify.com/track/4UMIv5jd9gK98a39BQRD9X',
#   'popuarity': 75,
#   'song_added': '2023-11-29T12:18:27Z',
#   'album_id': '4kIPlpwEZBK9JaI9pZHe79',
#   'artist_id': '1wRPtKGflJrBx9BmLsSwlU'},
#  {'song_id': '73K33p4Vyz9koXGqmL5eFs',
# ...

# %%
album_df=pd.DataFrame(album_list)
album_df.head()
# Out:
#                  album_id                                             name  \
# 0  15CyNDuGY5fsG0Hn9rjnpG                                   Champagne Talk
# 1  6BHlJhCk1vjCG6hqTG2SFV                                  Kahani Suno 2.0
# 2  4kIPlpwEZBK9JaI9pZHe79  Brahmastra (Original Motion Picture Soundtrack)
# 3  7khRLZe8P6XcUoRgOa3nnf                                     Malang Sajna
# 4  5AivaZj0CiQJoDWqVH2pbh                                     Still Rollin
#
#   release_date  total_tracks  \
# 0   2022-10-12             8
# 1   2022-05-31             1
# 2   2022-10-06             9
# 3   2022-12-19             1
# 4   2023-05-19             7
#
#                                                  url
# 0  https://open.spotify.com/album/15CyNDuGY5fsG0H...
# 1  https://open.spotify.com/album/6BHlJhCk1vjCG6h...
# 2  https://open.spotify.com/album/4kIPlpwEZBK9JaI...
# 3  https://open.spotify.com/album/7khRLZe8P6XcUoR...
# 4  https://open.spotify.com/album/5AivaZj0CiQJoDW...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df=album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df=pd.DataFrame(artist_list)
artist_df.head()
# Out:
#                 artist_id           artist_name  \
# 0  5NHm4TU5Twz7owibYxJfFU                  King
# 1  1n9EM0Y4A89vuRiA93gSS9          Kaifi Khalil
# 2  1wRPtKGflJrBx9BmLsSwlU                Pritam
# 3  4YRxDV8wJFPHPTeXepOstw          Arijit Singh
# 4  2fMqTqiTxUDlmcOEPaQSsx  Amitabh Bhattacharya
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/5NHm4TU5Twz...
# 1  https://api.spotify.com/v1/artists/1n9EM0Y4A89...
# 2  https://api.spotify.com/v1/artists/1wRPtKGflJr...
# 3  https://api.spotify.com/v1/artists/4YRxDV8wJFP...
# 4  https://api.spotify.com/v1/artists/2fMqTqiTxUD...

# %%
artist_df=artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df=pd.DataFrame(song_list)
song_df.head()
# Out:
#                   song_id        song_name  duration_ms  \
# 0  1418IuVKQPTYqt7QNJ9RXN   Maan Meri Jaan       194653
# 1  4VsP4Dm8gsibRxB5I2hEkw  Kahani Suno 2.0       173637
# 2  4UMIv5jd9gK98a39BQRD9X         Kesariya       268164
# 3  73K33p4Vyz9koXGqmL5eFs     Malang Sajna       161041
# 4  4eBvRhTJ2AcxCsbfTUjoRp          Cheques       183756
#
#                                                  url  popuarity  \
# 0  https://open.spotify.com/track/1418IuVKQPTYqt7...         79
# 1  https://open.spotify.com/track/4VsP4Dm8gsibRxB...         77
# 2  https://open.spotify.com/track/4UMIv5jd9gK98a3...         75
# 3  https://open.spotify.com/track/73K33p4Vyz9koXG...         79
# 4  https://open.spotify.com/track/4eBvRhTJ2AcxCsb...         81
#
#              song_added                album_id               artist_id
# 0  2023-11-29T12:18:27Z  15CyNDuGY5fsG0Hn9rjnpG  5NHm4TU5Twz7owibYxJfFU
# 1  2023-11-29T12:18:27Z  6BHlJhCk1vjCG6hqTG2SFV  1n9EM0Y4A89vuRiA93gSS9
# ...

# %%
album_df['release_date']=pd.to_datetime(album_df['release_date'])
song_df['song_added']=pd.to_datetime(song_df['song_added'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      49 non-null     object
#  1   name          49 non-null     object
#  2   release_date  49 non-null     datetime64[ns]
#  3   total_tracks  49 non-null     int64
#  4   url           49 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.3+ KB

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popuarity    50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB
